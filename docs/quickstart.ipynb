# %%
# %load_ext autoreload
# %autoreload 2 
import pandas as pd

from lactopy.lactate_models.general.OBLA import OBLA
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('data/test.csv')
intenisty = df['watt'].to_numpy()
lactate = df['lactate'].to_numpy()

# %%
obla = OBLA()
obla.fit(intenisty, lactate)
# Out:
# OBLA()

# %%
obla.plot.plot_fit()
# Out:
# <Axes: title={'center': 'Lactate Model Fit'}, xlabel='Intensity', ylabel='Lactate'>

# %%
obla.predict(3.4)
# Out:
# np.float64(136.72093462094782)

# %%
obla.plot.plot_predictions(3.4)
# Out:
# <Axes: title={'center': 'Lactate Model Fit'}, xlabel='Intensity', ylabel='Lactate'>
